# %% [markdown]
# # Install libraries

# %%
# %%capture
pip install faiss-cpu sentence-transformers pandas numpy textblob torch;

# %%
from sentence_transformers import SentenceTransformer
import faiss
from collections import Counter
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from transformers import pipeline

import numpy as np
import pandas as pd
from textblob import TextBlob
import pandas as pd
import re
import json

from sqlalchemy import create_engine
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rashbirkohli/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
def connect_db():
    db_user = 'admin'
    db_password = 'admin123'
    db_host = 'localhost'
    db_port = '5432'
    db_name = 'symentic_analysis'
    engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')
    return engine

# %%
def get_data(table_name, engine):
    data = pd.read_sql(
    f"SELECT * FROM {table_name}", 
    con=engine)
    return data

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', ' ', text)             # remove punctuation
    text = re.sub(r'[!"#$%&\'()*+,\-./:;<=>?@[\\\]^_`{|}~]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()  # normalize whitespace
    words = text.split()
    filtered_words = [w for w in words if w not in stop_words]
    return ' '.join(filtered_words)

# %%
def remove_urls(text):
    return re.sub(r'http\S+|www\.\S+', '', str(text))

# %%
def remove_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F" 
        "\U0001F300-\U0001F5FF"  
        "\U0001F680-\U0001F6FF"  
        "\U0001F1E0-\U0001F1FF" 
        "\U00002500-\U00002BEF"  
        "\U00002702-\U000027B0"
        "\U000024C2-\U0001F251"
        "\U0001f926-\U0001f937"
        "\U00010000-\U0010ffff"
        "\u2640-\u2642" 
        "\u2600-\u2B55"
        "\u200d"
        "\u23cf"
        "\u23e9"
        "\u231a"
        "\ufe0f"               
        "\u3030"
        "]+", flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', str(text))

# %%
def get_semantic_score(text):
    if not text or pd.isnull(text):
        return {'label': 'NEUTRAL', 'score': 0.0}
    result = classifier(text[:512])[0]
    return result

# %%
get_semantic_score('Sleep_well')
# Out:
# {'label': 'NEGATIVE', 'score': 0.997368574142456}

# %%
def preprocess_narrative(text):
    text = remove_urls(text)
    text = remove_emojis(text)
    text = clean_text(text)
    return text

# %%
engine = connect_db()
data = get_data('complaints', engine)[:1000]
data['cleaned_narrative'] = data['narrative'].fillna('').apply(preprocess_narrative)
data['sentiment_result'] = data['cleaned_narrative'].apply(get_semantic_score)
data['sentiment_label'] = data['sentiment_result'].apply(lambda x: x['label'])
data['sentiment_score'] = data['sentiment_result'].apply(lambda x: x['score'])
data['embedding'] = model.encode(data['cleaned_narrative'].fillna(''), normalize_embeddings=True).tolist()
data['embedding_json'] = data['embedding'].apply(lambda x: json.dumps(x))

# %%
data.columns
# Out:
# Index(['Complaint_No', 'product', 'narrative', 'cleaned_narrative',
#        'sentiment_result', 'sentiment_label', 'sentiment_score', 'embedding',
#        'embedding_json'],
#       dtype='object')

# %%
data.head()
# Out:
#    Complaint_No           product  \
# 0             0       credit_card
# 1             1       credit_card
# 2             2    retail_banking
# 3             3  credit_reporting
# 4             4  credit_reporting
#
#                                            narrative  \
# 0  purchase order day shipping amount receive pro...
# 1  forwarded message date tue subject please inve...
# 2  forwarded message cc sent friday pdt subject f...
# 3  payment history missing credit report speciali...
# 4  payment history missing credit report made mis...
#
#                                    cleaned_narrative  \
# 0  purchase order day shipping amount receive pro...
# 1  forwarded message date tue subject please inve...
# 2  forwarded message cc sent friday pdt subject f...
# 3  payment history missing credit report speciali...
# 4  payment history missing credit report made mis...
#
#                                     sentiment_result sentiment_label  \
# 0  {'label': 'NEGATIVE', 'score': 0.9755858182907...        NEGATIVE
# 1  {'label': 'NEGATIVE', 'score': 0.9893458485603...        NEGATIVE
# 2  {'label': 'NEGATIVE', 'score': 0.9958861470222...        NEGATIVE
# 3  {'label': 'NEGATIVE', 'score': 0.9983856678009...        NEGATIVE
# 4  {'label': 'NEGATIVE', 'score': 0.9976465106010...        NEGATIVE
#
#    sentiment_score                                          embedding  \
# 0         0.975586  [-0.060630906373262405, -0.04419517144560814, ...
# 1         0.989346  [-0.02163921296596527, 0.025052763521671295, -...
# 2         0.995886  [-0.04444830119609833, 0.014120331034064293, 0...
# 3         0.998386  [-0.016904840245842934, -0.04727127403020859, ...
# 4         0.997647  [0.011618228629231453, -0.016998833045363426, ...
#
#                                       embedding_json
# 0  [-0.060630906373262405, -0.04419517144560814, ...
# 1  [-0.02163921296596527, 0.025052763521671295, -...
# 2  [-0.04444830119609833, 0.014120331034064293, 0...
# 3  [-0.016904840245842934, -0.04727127403020859, ...
# 4  [0.011618228629231453, -0.016998833045363426, ...

# %%
column_list = ['Complaint_No', 'product', 'narrative', 'cleaned_narrative', 'sentiment_label', 'sentiment_score', 'embedding_json']

# %%
data[column_list].to_sql('complaints_embedded_data', engine, if_exists='append', index=False)

# %%
df_embed[df_embed.Complaint_No == 66]
# Out:
#     Complaint_No      product  \
# 77            66  credit_card
#
#                                             narrative  \
# 77  paid hsbc credit card said would send paid ful...
#
#                                     cleaned_narrative sentiment_result  \
# 77  paid hsbc credit card said would send paid ful...             None
#
#    sentiment_label  sentiment_score  \
# 77        NEGATIVE         0.996875
#
#                                             embedding  \
# 77  [-0.030540751293301582, 0.031236765906214714, ...
#
#                                        embedding_json
# 77  [-0.030540751293301582, 0.031236765906214714, ...

# %%
df_embed = get_data('complaints_embedded_data', engine)
df_embed['embedding'] = df_embed['embedding_json'].apply(json.loads)
embeddings = np.vstack(df_embed['embedding'].to_numpy())

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

def search_semantic(query, top_k=10):
    query_vec = model.encode([query], normalize_embeddings=True)
    D, I = index.search(np.array(query_vec), top_k)
    return df_embed.iloc[I[0]][['Complaint_No', 'product', 'narrative', 'sentiment_label', 'sentiment_score']]

# %%
search_semantic("delayed refund from bank", top_k=10)
# Out:
#     Complaint_No              product  \
# 77            66          credit_card
# 4             11          credit_card
# 57            50       retail_banking
# 83            85     credit_reporting
# 9             17  mortgages_and_loans
# 69            60  mortgages_and_loans
# 22            19     credit_reporting
# 23            20     credit_reporting
# 1              1          credit_card
# 40            36       retail_banking
#
#                                             narrative sentiment_label  \
# 77  paid hsbc credit card said would send paid ful...        NEGATIVE
# 4   called request new york state covid relief pla...        NEGATIVE
# 57  usaa punishing customer closing account report...        NEGATIVE
# 83  shocked reviewed credit report found late paym...        NEGATIVE
# 9   closed mortgage dovenmuhle mortgage paid full ...        NEGATIVE
# 69  paid remaining balance account credit account ...        NEGATIVE
# 22  xxxxxxxx credit card year disputed charge vend...        NEGATIVE
# 23  xxxxxxxx credit card year disputed charge vend...        NEGATIVE
# 1   forwarded message date tue subject please inve...        NEGATIVE
# 40  sent message via secure message home banking c...        NEGATIVE
#
#     sentiment_score
# 77         0.996875
# 4          0.991700
# 57         0.996293
# 83         0.996952
# 9          0.997662
# 69         0.993267
# 22         0.993513
# 23         0.995478
# 1          0.989346
# 40         0.997569
