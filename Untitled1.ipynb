# %%
pip install psycopg2-binary
# Out:
# ...
#      |████████████████████████████████| 385 kB 8.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/rashbirkohli/opt/anaconda3/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/rv/f2zrsvz938zbcz07l0tqftn00000gn/T/pip-install-ytzrpizu/psycopg2-binary_33d919dadf2f486a96fe89914de5da07/setup.py'"'"'; __file__='"'"'/private/var/folders/rv/f2zrsvz938zbcz07l0tqftn00000gn/T/pip-install-ytzrpizu/psycopg2-binary_33d919dadf2f486a96fe89914de5da07/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/rv/f2zrsvz938zbcz07l0tqftn00000gn/T/pip-pip-egg-info-4v3czbqs
#          cwd: /private/var/folders/rv/f2zrsvz938zbcz07l0tqftn00000gn/T/pip-install-ytzrpizu/psycopg2-binary_33d919dadf2f486a96fe89914de5da07/
#     Complete output (23 lines):
# ...

# %%
pip install pandas sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
 
# --- DB credentials ---
db_user = 'admin'
db_password = 'admin123'
db_host = 'localhost'  # or '127.0.0.1'
db_port = '5432'
db_name = 'symentic_analysis'
table_name = 'complaints'  # change to your target table

# --- Read CSV ---
df = pd.read_csv('complaints.csv')
df.rename(columns={'Unnamed: 0': 'Complaint_No'}, inplace=True)

# --- Create SQLAlchemy engine ---
engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

# --- Insert into DB ---
df.to_sql(table_name, engine, if_exists='append', index=False)

print("CSV data inserted successfully!")
# Out:
# CSV data inserted successfully!

# %%
# --- DB credentials ---
db_user = 'admin'
db_password = 'admin123'
db_host = 'localhost'  # or '127.0.0.1'
db_port = '5432'
db_name = 'symentic_analysis'
table_name = 'bank_reviews3'  # change to your target table

# --- Read CSV ---
df = pd.read_csv('bank_reviews3.csv')

# --- Create SQLAlchemy engine ---
engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

# --- Insert into DB ---
df.to_sql(table_name, engine, if_exists='append', index=False)

print("CSV data inserted successfully!")
# Out:
# CSV data inserted successfully!
